# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.5/898.5 kB 20.7 MB/s eta 0:00:0000:01
# ...

# %%
from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/kaggle/input/fingergestures/data.yaml epochs=100 batch=16 imgsz=640 plots=True
# Out:
# ...
# 100%|███████████████████████████████████████| 6.25M/6.25M [00:00<00:00, 118MB/s]
# Ultralytics 8.3.40 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
Image(filename='/kaggle/working/runs/detect/train/results.png', width=600)

# %%
Image(filename='/kaggle/working/runs/detect/train/confusion_matrix.png', width=600)

# %%
Image(filename='/kaggle/working/runs/detect/train2/val_batch1_labels.jpg', width=600)
